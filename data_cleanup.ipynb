# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
calendar = "calendar.csv"
listings = "listings.csv"
reviews = "reviews.csv"

# %%
calendar_data = pd.read_csv(calendar)
listings_data = pd.read_csv(listings)
reviews_data = pd.read_csv(reviews)

listings_data.head()
# Out:
#         id                           listing_url     scrape_id last_scraped  \
# 0  9448215  https://www.airbnb.com/rooms/9448215  2.020000e+13     1/4/2016
# 1  7204672  https://www.airbnb.com/rooms/7204672  2.020000e+13     1/4/2016
# 2  5579427  https://www.airbnb.com/rooms/5579427  2.020000e+13     1/4/2016
# 3  6734621  https://www.airbnb.com/rooms/6734621  2.020000e+13     1/4/2016
# 4  2263643  https://www.airbnb.com/rooms/2263643  2.020000e+13     1/4/2016
#
#                                   name  \
# 0                         Capital hill
# 1    Magnolia charm, close to downtown
# 2  Steps from magical Discovery Park-3
# 3  Super location, 3.5ba, Free Parking
# 4        Charming English room by Park
#
#                                              summary  \
# 0  Large room in Seattle's best neighborhood,  ca...
# 1  Our house is just miles from the excitement of...
# 2  A truly magnificent location in the heart of S...
# 3  This Magnolia townhouse (3 bdrm+loft, 3.5 bath...
# 4  I live near a park and also a 20 minute busrid...
#
#                                                space  \
# 0                                                NaN
# 1  Our spacious home is perfect for a family or c...
# 2  WELCOME TO SEATTLE!!!    I'm a professional ja...
# 3  This house was expertly picked because of loca...
# 4  This is a large bedroom with closet, desk and ...
#
#                                          description experiences_offered  \
# 0  Large room in Seattle's best neighborhood,  ca...                none
# 1  Our house is just miles from the excitement of...                none
# 2  A truly magnificent location in the heart of S...                none
# 3  This Magnolia townhouse (3 bdrm+loft, 3.5 bath...                none
# 4  I live near a park and also a 20 minute busrid...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1  We live on a dead-end street and the house loo...        ...
# 2  Magnolia has an "island" mentality and feel, t...        ...
# 3  The part of Magnolia lies on the edge of Inter...        ...
# 4                                                NaN        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN         WASHINGTON
# 1                 9.0                f     NaN         WASHINGTON
# 2                10.0                f     NaN         WASHINGTON
# 3                10.0                f     NaN         WASHINGTON
# 4                 9.0                f     NaN         WASHINGTON
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f            flexible                              f
# 1                f            moderate                              f
# 2                f              strict                              f
# 3                t            moderate                              f
# 4                f            flexible                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              3
# 1                                f                              1
# 2                                f                              4
# 3                                f                              1
# 4                                f                              2
#
#   reviews_per_month
# 0              1.00
# 1              0.43
# 2              0.74
# 3              4.24
# 4              3.01
#
# [5 rows x 92 columns]

# %%
listings_df = listings_data[['id', 'neighbourhood_cleansed', 'room_type',
                            'zipcode','latitude','longitude', 'property_type', 'price','number_of_reviews',
                            'review_scores_rating', 'reviews_per_month', 'square_feet']]

listings_df.head()
# Out:
#         id neighbourhood_cleansed        room_type  zipcode   latitude  \
# 0  9448215                  Minor     Private room  98122.0  47.611079
# 1  7204672            Lawton Park  Entire home/apt  98199.0  47.659470
# 2  5579427            Lawton Park  Entire home/apt  98199.0  47.654211
# 3  6734621            Lawton Park  Entire home/apt  98199.0  47.651031
# 4  2263643            Lawton Park     Private room  98199.0  47.659121
#
#     longitude property_type     price  number_of_reviews  \
# 0 -122.312820         House   $67.00                   1
# 1 -122.401873         House  $200.00                   2
# 2 -122.408389         House  $229.00                   4
# 3 -122.385004     Townhouse  $333.00                  29
# 4 -122.402265     Apartment   $41.00                  57
#
#    review_scores_rating  reviews_per_month  square_feet
# 0                 100.0               1.00          NaN
# 1                  90.0               0.43          NaN
# 2                 100.0               0.74          NaN
# 3                  94.0               4.24          NaN
# 4                  89.0               3.01          NaN

# %%
listings_df['price'] = pd.to_numeric(listings_df['price'].apply(lambda x:x.replace('$', '').replace(',','')))
# Out:
# C:\Users\brizzle\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
listings_df.head()
# Out:
#         id neighbourhood_cleansed        room_type  zipcode   latitude  \
# 0  9448215                  Minor     Private room  98122.0  47.611079
# 1  7204672            Lawton Park  Entire home/apt  98199.0  47.659470
# 2  5579427            Lawton Park  Entire home/apt  98199.0  47.654211
# 3  6734621            Lawton Park  Entire home/apt  98199.0  47.651031
# 4  2263643            Lawton Park     Private room  98199.0  47.659121
#
#     longitude property_type  price  number_of_reviews  review_scores_rating  \
# 0 -122.312820         House   67.0                  1                 100.0
# 1 -122.401873         House  200.0                  2                  90.0
# 2 -122.408389         House  229.0                  4                 100.0
# 3 -122.385004     Townhouse  333.0                 29                  94.0
# 4 -122.402265     Apartment   41.0                 57                  89.0
#
#    reviews_per_month  square_feet
# 0               1.00          NaN
# 1               0.43          NaN
# 2               0.74          NaN
# 3               4.24          NaN
# 4               3.01          NaN

# %%
listings_df.describe()
# Out:
#                  id       zipcode     latitude    longitude        price  \
# count  3.818000e+03   3811.000000  3818.000000  3818.000000  3818.000000
# mean   5.550111e+06  98115.696405    47.628961  -122.333103   127.976166
# std    2.962660e+06     16.488203     0.043052     0.031745    90.250022
# min    3.335000e+03  98101.000000    47.505088  -122.417219    20.000000
# 25%    3.258256e+06  98104.000000    47.609418  -122.354321    75.000000
# 50%    6.118244e+06  98112.000000    47.623601  -122.328874   100.000000
# 75%    8.035127e+06  98121.000000    47.662694  -122.310800   150.000000
# max    1.034016e+07  98199.000000    47.733358  -122.240607  1000.000000
#
#        number_of_reviews  review_scores_rating  reviews_per_month  square_feet
# count        3818.000000           3171.000000        3191.000000    97.000000
# mean           22.223415             94.539262           2.078919   854.618557
# std            37.730892              6.606083           1.822348   671.404893
# min             0.000000             20.000000           0.020000     0.000000
# 25%             2.000000             93.000000           0.695000   420.000000
# 50%             9.000000             96.000000           1.540000   750.000000
# 75%            26.000000             99.000000           3.000000  1200.000000
# max           474.000000            100.000000          12.150000  3000.000000

# %%
listings_df.fillna(value=0)
# Out:
#             id neighbourhood_cleansed        room_type  zipcode   latitude  \
# 0      9448215                  Minor     Private room  98122.0  47.611079
# 1      7204672            Lawton Park  Entire home/apt  98199.0  47.659470
# 2      5579427            Lawton Park  Entire home/apt  98199.0  47.654211
# 3      6734621            Lawton Park  Entire home/apt  98199.0  47.651031
# 4      2263643            Lawton Park     Private room  98199.0  47.659121
# 5      4608208            Lawton Park     Private room  98199.0  47.664035
# 6      9999955            Lawton Park     Private room  98199.0  47.651571
# 7      3528627            Lawton Park     Private room  98199.0  47.659830
# 8      8048333            Lawton Park  Entire home/apt  98199.0  47.653980
# 2                    100.0               0.74          0.0
# 3                     94.0               4.24          0.0
# 4                     89.0               3.01          0.0
# 5                     98.0               3.03          0.0
# 6                      0.0               0.00          0.0
# 7                     86.0               1.11          0.0
# 8                      0.0               0.00          0.0
# 9                    100.0               0.75          0.0
# 10                    94.0               1.54          0.0
# 11                    98.0               1.33          0.0
# 12                     0.0               0.00          0.0
# 13                    94.0               5.26          0.0
# 14                     0.0               0.00          0.0
# 15                    91.0               0.50          0.0
# 16                    97.0               1.25          0.0
# 17                   100.0               0.49          0.0
# 18                   100.0               0.64          0.0
# 19                     0.0               0.00          0.0
# 20                    97.0               0.95          0.0
# 21                   100.0               2.08          0.0
# 22                     0.0               0.00          0.0
# 23                     0.0               0.00          0.0
# 24                    80.0               0.50          0.0
# 25                   100.0               0.47        250.0
# 26                    60.0               0.30          0.0
# 27                     0.0               0.00          0.0
# 28                    73.0               0.49          0.0
# 29                    93.0               5.98          0.0
# ...                    ...                ...          ...
# 3788                  91.0               6.00          0.0
# 3789                  94.0               1.60          0.0
# 3790                  83.0               3.13          0.0
# 3791                  98.0               1.82          0.0
# 3792                 100.0               0.81          0.0
# 3793                  97.0               2.86          0.0
# 3794                 100.0               3.69          0.0
# 3795                   0.0               0.00          0.0
# 3796                  93.0               1.57          0.0
# 3797                  93.0               3.04          0.0
# 3798                  98.0               0.72          0.0
# 3799                  93.0               0.99          0.0
# 3800                   0.0               0.00          0.0
# 3801                  98.0               0.49          0.0
# 3802                  94.0               4.63          0.0
# 3803                  98.0               0.58          0.0
# 3804                  96.0               2.39          0.0
# 3805                   0.0               0.00          0.0
# 3806                  95.0               0.34          0.0
# 3807                  80.0               2.93          0.0
# 3808                  74.0               2.48          0.0
# 3809                  97.0               0.90          0.0
# 3810                  93.0               2.00          0.0
# 3811                  91.0               5.15          0.0
# 3812                 100.0               0.04          0.0
# 3813                  97.0               3.46          0.0
# 3814                  87.0               4.62          0.0
# 3815                  92.0               0.27        300.0
# 3816                  95.0               1.91          0.0
# 3817                   0.0               0.00          0.0
#
# [3818 rows x 12 columns]

# %%
listings_df['square_feet'].isnull().sum()
# Out:
# 3721

# %%
# listings_df['zipcode'].isnull().sum()

# %%
# listings_df = listings_df.dropna(axis=0)

# %%
listings_df['property_type'].value_counts()

# %%
listings_df['potential_annual_revenue']= listings_df['price']*365*.33

# %%
zipcode_values = pd.read_csv('HV_zipcode.csv', encoding='latin1')

values = zipcode_values[['RegionName', 'Zhvi']]
values = values.rename(columns={'RegionName':'zipcode', 'Zhvi': 'Zillow_Avg_Value'})
values

# %%
merged_df = pd.merge(listings_df, values, how='left', on=['zipcode', 'zipcode'])

# %%
merged_df.head()

# %%
merged_df['yield']= merged_df['potential_annual_revenue'] / merged_df['Zillow_Avg_Value'] *100
merged_df['rent_squre_foot']= merged_df['potential_annual_revenue'] / merged_df['square_feet']
merged_df['rent_squre_foot'] = merged_df['rent_squre_foot'].apply(lambda x: round(x,2))



merged_df.head()

# %%
merged_df.to_csv('cleaned_data.csv')
